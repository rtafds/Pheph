# %% [markdown]
# ### This library is to find the best explanatory variables.
# - First, learning the relationship between explanatory variables and objective variables.
# - Second, find an explanatory variable that maximizes the evaluation value created from the objective variable in GA

# %%
import pandas as pd
import numpy as np
from pheph import Pheph
import random

# %%
pheph = Pheph()

# %%
#df = pd.read_csv("../datasets/adult_raw.csv")
df = pd.read_csv("../datasets/chemical.csv")

# %%
df
# Out:
#           x1        x2        x3        x4        y1        y2        y3
# 0   0.221993  0.870732  0.206719  0.918611  3.962458  1.701078  1.556572
# 1   0.488411  0.611744  0.765908  0.518418  4.957532  1.384165 -2.223486
# 2   0.296801  0.187721  0.080741  0.738440  3.761158  0.629912  0.532550
# 3   0.441309  0.158310  0.879937  0.274086  5.135732  1.153340 -3.932084
# 4   0.414235  0.296080  0.628788  0.579838  5.353030  0.863543 -2.156681
# 5   0.599929  0.265819  0.284686  0.253588  1.470306  0.697797 -0.568407
# 6   0.327564  0.144164  0.165613  0.963931  5.284256  1.216232  0.412452
# 7   0.960227  0.188415  0.024307  0.204556 -1.692796  0.997492  1.997438
# 8   0.699844  0.779515  0.022933  0.577663  0.318351  1.418851  2.257829
# 9   0.001642  0.515473  0.639795  0.985624  7.595666  1.472972 -1.196575
# 10  0.259098  0.802497  0.870483  0.922750  7.476766  2.287695 -1.886942
# 11  0.002214  0.469488  0.981469  0.398945  6.461214  1.193395 -3.809210
# ...

# %%
exp = [0,1,2,3]  # 
obj = [4,5,6]
algorithms = "GradientBoostingRegressor"

#algorithms = 'GaussianProcessRegressor'

# %%
# learning 
pheph.fit(df, exp, obj, algorithms=algorithms)
# Out:
# [[],
#  [Pipeline(steps=[('scale', StandardScaler()),
#                   ('est', GradientBoostingRegressor())]),
#   Pipeline(steps=[('scale', StandardScaler()),
#                   ('est', GradientBoostingRegressor())]),
#   Pipeline(steps=[('scale', StandardScaler()),
#                   ('est', GradientBoostingRegressor())])]]

# %%
weights = (1,5,3)  # if this setting, the evaluate values is y1+5*y2+3*y3

# %%
best_ind, best_ind_value, pop, pop_save = pheph.inverse_fit(df, weights=weights)
# Out:
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/deap/creator.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return numpy.array(list(iterable)).view(cls)
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...

# %%
best_ind
# Out:
# Individual([(0, 0), 1.0091129794250555, 1.0047622529133797,
#             0.44664587934021693, 0.9063684623934192], dtype=object)

# %%
best_ind_value
# Out:
# (15.642106780589417,)

# %%
individual = pop_save[0][0]

# %%
individual
# Out:
# Individual([(0, 0), 0.0506410472483113, 0.617949387252107,
#             0.5437909160122602, 0.7236127695896779], dtype=object)

# %%
def _mutDomain(individual, domain_list, indpb=0.05):
    """GA mutation function. Mutate according to the domain definition.
    Any mutation can be set.
    domain_list (list) : domain.values to list, choice2 without index.
    """
    
    for i in range(len(domain_list)):
        if random.random() < indpb:
            # individual is i+1 because first chromosome of invividual is (0,0), 
            # for dealing with bugs in deap that cannot handle tuples unless the tuple is first.
            if domain_list[i][0]=='randint':
                individual[i+1] = eval('random.randint{}'.format(domain_list[i][1]))
            elif domain_list[i][0]=='uniform':
                individual[i+1] = eval('random.uniform{}'.format(domain_list[i][1]))        
            elif domain_list[i][0]=='choice':
                individual[i+1] = eval('random.choice({})'.format(domain_list[i][1]))        

            elif domain_list[i][0]=='choice2':
                # When a choice2 function is included
                #if isinstance(domain_list[i][1], tuple) or isinstance(domain_list[i][1],list):
                    
                individual[i+1] = eval('random.choice({})'.format(domain_list[i][1]))  
                # When choice2 index is included
                #else:
                #    pass

            elif domain_list[i][0]=='randrange':
                individual[i+1] = eval('random.randrange{}'.format(domain_list[i][1])) 

    return individual,

# %%
domain = pheph.domain
domain_ = list(domain.values())
domain_list = []
domain_list_append = domain_list.append
for i, dom in enumerate(domain_):    
    if domain_[i][0]=='choice2':
        if isinstance(domain_[i][1], tuple) or isinstance(domain_[i][1],list):
            domain_list_append(dom)
    else:
        domain_list_append(dom)

# %%
individual
# Out:
# Individual([(0, 0), 0.0506410472483113, 0.617949387252107,
#             0.5437909160122602, 0.7236127695896779], dtype=object)

# %%
_mutDomain(individual, domain_list)
# Out:
# (Individual([(0, 0), 0.0506410472483113, 0.617949387252107,
#              0.5437909160122602, 0.7236127695896779], dtype=object),)

# %%
# from pop_save from GA and raw_data, sort from those with the highest rating
fit_data = pheph.ga_restore(pop_save, df)

# %%
fit_data  # YEAH!!!
# Out:
#             x1        x2        x3        x4        y1        y2        y3  \
# 4533  0.955256  0.993138  0.446646  0.906368  4.045483  2.580724  2.524698
# 4182  0.955256  0.970135  0.446646  0.906368  4.045483  2.580724  2.524698
# 4874  0.955256  0.977428  0.446646  0.906368  4.045483  2.580724  2.524698
# 5018  0.955256  0.997508  0.446646  0.906368  4.045483  2.580724  2.524698
# 4790  0.961653  0.993138  0.446646  0.906368  4.045483  2.580724  2.524698
# ...        ...       ...       ...       ...       ...       ...       ...
# 47   -0.005337  0.041066 -0.068837  0.144941  0.259822  0.167780  0.760421
# 20    0.354338  0.129618  0.535817  0.202955  4.089066  0.749880 -3.273924
# 42    0.355707  0.243679  0.693198  0.248392  4.276931  0.680742 -3.309479
# 13    0.029112  0.086526  0.111454  0.251245  1.795979  0.041967 -0.321092
# 85    0.083333  0.099379  0.643565 -0.018354  5.030960  0.418995 -3.335091
#
#      data_type  fitness_value
# 4533   predict      15.313346
# ...
