# %% [markdown]
# ### This library is to find the best explanatory variables.
# - First, learning the relationship between explanatory variables and objective variables.
# - Second, find an explanatory variable that maximizes the evaluation value created from the objective variable in GA

# %%
import pandas as pd
import numpy as np
from pheph import Pheph

# %%
pheph = Pheph()

# %%
#df = pd.read_csv("../datasets/adult_raw.csv")
# this data from https://github.com/starrydata/starrydata_datasets
df = pd.read_csv("../datasets/20190711_preprocessing_interpolated_data.csv")

# %%
#df_fillna = pheph.complena(df)  # now, error.
#df_dropna = df.dropna()

# %%
def ZT(S, sigma, kappa, T):
    return S^2*simga*T/kappa

# %%
df
# Out:
#        sampleid                  composition  Temperature  \
# 0          2871                      Co2TiSn           50
# 1           520                 Al3V0.7Ti0.3           50
# 2          7488                      Cu4SnS4           50
# 3           519                 Al3V0.9Ti0.1           50
# 4           519                 Al3V0.9Ti0.1           50
# ...         ...                          ...          ...
# 35079     10268                       ZrNiSn         1050
# 35080     10588   Hf0.6Zr0.4NiSn0.995Sb0.005         1100
# 35081     11562   Zr0.8Hf0.2NiSn0.985Sb0.015         1100
# 35082     10584  Hf0.6Zr0.4NiSn0.995Sb0.005          1100
# 35083     10585   Hf0.6Zr0.4NiSn0.995Sb0.005         1100
#
#        Seebeck coefficient  Thermal conductivity            ZT  \
# 0            -2.099039e-06              6.120639  1.460192e-05
# 1             4.152977e-07              2.091992  2.033693e-06
# 2            -1.098690e-05              1.094734  3.258619e-07
# 3            -5.918045e-06              1.973540  3.907300e-04
# 4            -2.272093e-06              2.169064  6.137344e-05
# ...                    ...                   ...           ...
# 35079        -1.888979e-04              7.240004  1.147480e+00
# 35080        -2.160877e-04              4.275876  1.261694e+00
# 35081        -2.026912e-04              5.201152  1.058077e+00
# 35082        -2.074550e-04              4.373700  1.130896e+00
# 35083        -2.009425e-04              4.540884  1.033897e+00
#
#        Electrical conductivity
# 0                405691.084444
# 1                493351.634207
# 2                    59.104726
# 3                440348.250829
# 4                515740.035759
# ...                        ...
# 35079            221738.100710
# 35080            110989.150655
# 35081            130559.045790
# 35082            112926.531471
# 35083            115196.669394
#
# [35084 rows x 7 columns]

# %%
#df_formatting, dummies_list, categories_reborn, category_colnames = pheph.formatting(df_dropna, dummies=["workclass","education","marital-status","occupation", "relationship", "race","native-country"],categories=["sex","class"])

# %%
exp = [0,1,2,3]  # 
obj = [4,5,6]
algorithms = "GradientBoostingRegressor"

#algorithms = 'GaussianProcessRegressor'

# %%
# learning 
pheph.fit(df, exp, obj, algorithms=algorithms)
# Out:
# [[],
#  [Pipeline(steps=[('scale', StandardScaler()),
#                   ('est', GradientBoostingRegressor())]),
#   Pipeline(steps=[('scale', StandardScaler()),
#                   ('est', GradientBoostingRegressor())]),
#   Pipeline(steps=[('scale', StandardScaler()),
#                   ('est', GradientBoostingRegressor())])]]

# %%
weights = (1,5,3)  # if this setting, the evaluate values is y1+5*y2+3*y3

# %%
best_ind, best_ind_value, pop, pop_save = pheph.inverse_fit(df, weights=weights)
# Out:
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/deap/creator.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return numpy.array(list(iterable)).view(cls)
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/smamitsu/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
best_ind
# Out:
# Individual([(0, 0), 0.9552557021297846, 0.9931377641718016,
#             0.44664587934021693, 0.9063684623934192], dtype=object)

# %%
best_ind_value
# Out:
# (15.313346130004753,)

# %%
# from pop_save from GA and raw_data, sort from those with the highest rating
fit_data = pheph.ga_restore(pop_save, df)

# %%
fit_data  # YEAH!!!
# Out:
#             x1        x2        x3        x4        y1        y2        y3  \
# 4533  0.955256  0.993138  0.446646  0.906368  4.045483  2.580724  2.524698
# 4182  0.955256  0.970135  0.446646  0.906368  4.045483  2.580724  2.524698
# 4874  0.955256  0.977428  0.446646  0.906368  4.045483  2.580724  2.524698
# 5018  0.955256  0.997508  0.446646  0.906368  4.045483  2.580724  2.524698
# 4790  0.961653  0.993138  0.446646  0.906368  4.045483  2.580724  2.524698
# ...        ...       ...       ...       ...       ...       ...       ...
# 47   -0.005337  0.041066 -0.068837  0.144941  0.259822  0.167780  0.760421
# 20    0.354338  0.129618  0.535817  0.202955  4.089066  0.749880 -3.273924
# 42    0.355707  0.243679  0.693198  0.248392  4.276931  0.680742 -3.309479
# 13    0.029112  0.086526  0.111454  0.251245  1.795979  0.041967 -0.321092
# 85    0.083333  0.099379  0.643565 -0.018354  5.030960  0.418995 -3.335091
#
#      data_type  fitness_value
# 4533   predict      15.313346
# 4182   predict      15.313346
# 4874   predict      15.313346
# 5018   predict      15.313346
# 4790   predict      15.313346
# ...        ...            ...
# 47     predict      -8.535396
# 20     predict      -8.786573
# 42     predict      -9.335042
# 13         raw     -10.704082
# 85     predict     -11.222034
#
# [856 rows x 9 columns]
